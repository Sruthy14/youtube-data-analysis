# %%
from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON

# %%
api_key = 'AIzaSyCxdvcbyD1gp_7x9JnICi5zQjkfekphbMI'

# %%
channel_ids = [#'UCsTcErHg8oDvUnTzoqsYeNw',
              #more channel ids
               'UCBJycsmduvYEL83R_U4JriQ',
               #'UCyfn04p-OsACM0kGfpcIvEg',
              ]

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
channel_stats = pd.DataFrame()

# %%
def get_channel_stats(youtube, channel_ids):

    all_data = []

    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()
    
    #loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
               'subscribers': item['statistics']['subscriberCount'],
               'views': item['statistics']['viewCount'],
               'totalVideos': item['statistics']['videoCount'],
               'playlistId': item['contentDetails']['relatedPlaylists']['uploads']
        }
        
    all_data.append(data)
        
    return(pd.DataFrame(all_data))

#channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#         channelName subscribers       views totalVideos  \
# 0  Marques Brownlee    16700000  3432058228        1531
#
#                  playlistId
# 0  UUBJycsmduvYEL83R_U4JriQ

# %%
playlist_id = "UUBJycsmduvYEL83R_U4JriQ"

def get_video_ids(youtube, playlist_id):
    
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId= playlist_id,
        maxResults = 50
    )
    response = request.execute()
    
    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])
        
    #next_page_token = response.get('nextPageToken')
#     while next_page_token is not None:
        
#         request = youtube.playlistItems().list(
#                     part="snippet,contentDetails",
#                     playlistId= playlist_id,
#                     maxResults = 50
#         )
#         response = request.execute()

#         for item in response['items']:
#             video_ids.append(item['contentDetails']['videoId'])

#         next_page_token = response.get('nextPageToken')
        
    return video_ids

#JSON(response)

# %%
video_ids = get_video_ids(youtube, playlist_id)

# %%
len(video_ids)
# Out:
# 50

# %%
def get_video_details(youtube, video_ids):

    all_video_info = []

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id= ','.join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tag', 'publishedAt'],
                            'statistics':['viewCount', 'likeCount','favoriteCount', 'commentCount'],
                            'contentDetails': ['duration', 'definition', 'caption']}
            video_info = {}
            video_info['video_id'] = video['id']
            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
        
    return pd.DataFrame(all_video_info)
#JSON(response)

# %%
video_df= get_video_details(youtube, video_ids)
video_df
# Out:
#        video_id      channelTitle  \
# 0   O-buiiyp_xU  Marques Brownlee
# 1   4PZSB9bV1Zg  Marques Brownlee
# 2   b7zBJNmdImo  Marques Brownlee
# 3   NEZSa5NEREs  Marques Brownlee
# 4   A18BST27Wpw  Marques Brownlee
# 5   1afpDuTb-P0  Marques Brownlee
# 6   a01edYZIfjc  Marques Brownlee
# 7   bi1XS6s1rBY  Marques Brownlee
# 8   mv9afG2Dm9I  Marques Brownlee
# 20  Galaxy S23 / Ultra Impressions: Cruise Control!
# 21             Apple HomePod 2 Review: I'm Confused
# 22             The #1 Most Overpriced Tech in 2023!
# 23            M2 Pro Mac Mini Review: Game Changer!
# 24        M2 Max MacBook Pro Review: Back to Bumps!
# 25                    4 Ways AI Can Save Microsoft!
# 26           This Phone is $169 - What's the Catch?
# 27              Is Apple Giving Magsafe to Android?
# 28                   Stop Reading Megapixel Counts!
# 29            What is Happening with iPhone Camera?
# 30                          Smartphone Awards 2022!
# 31               The Voice Assistant Battle! (2023)
# 32        100X Zoom in Phones Leveled Up This Year!
# 33                 The Best Smartphone Camera 2022!
# 34            Tesla Self Driving vs Everyday Roads!
# 35           3 iPhone Super Useful Hidden Features!
# 36            The Truth About AI Getting "Creative"
# 37                         When Apple Gets It Wrong
# 38                               My Tech Hot Takes!
# 39                         Remember the Cybertruck?
# 40          iPad Pro M2: What Does "Pro" Even Mean?
# 41                    Google Hits Back at iMessage!
# 42                  Lucid Air: How to One-up Tesla!
# 43                                    Dear Twitter!
# 44                 The iPhone USB-C Law: Explained!
# 45                   Who Cares About the Metaverse?
# 46                           The New iPad is Weird!
# 47      iPhone’s Crash Detection vs Roller Coasters
# 48           Pixel Watch Review: First Gen Fumbles!
# 49              Meta Quest Pro’s Passthrough mode 👀
#
#                                           description   tag  \
# 0   Everything in this Dope Tech has 1 thing in co...  None
# 1   It's expensive. But it's built like a tank.\n\...  None
# 2   This phone isn't even getting released outside...  None
# 3                                   Huawei Watch Buds  None
# 4   My setup tour and everyday carry for 2023.\n\n...  None
# 5   100X zoom pictures of the moon will never be t...  None
# 6   The new iPhone 14 yellow color is pretty... le...  None
# 7   VIVO X90 Pro+ has a gigantic, magical fingerpr...  None
# 8   I said yes to every review request I got for a...  None
# 9                                   One small step...  None
# 10  OnePlus made a concept phone\n\nMKBHD Merch: h...  None
# 11  Oppo Find N2 Flip has the best answer to the f...  None
# 12                        It's a Cola-Cola Smartphone  None
# 13  AI and Bing and ChatGPT are out of control... ...  None
# 14  Samsung's Galaxy S23 Ultra is a great minor (m...  None
# 15  OnePlus 11 is a flagship for $699\n\nMKBHD Mer...  None
# 16                      100X zoom is still ridiculous  None
# 17  AI is incredible, but it's not taking anyone's...  None
# 18  The evolution of the iPhone through integratio...  None
# 19  An alternate way of measuring F150 Lightning's...  None
# 20  Samsung's flagships for 2023 are a small bump ...  None
# 21  The second generation HomePod is really good. ...  None
# 22                                    It's not close.  None
# 23  This tiny computer out-benchmarks the base Mac...  None
# 24  It's an (impressive) bump instead of a quantum...  None
# 25                            Hear me out. AI Clippy.  None
# 26  Brand new budget phone vs older flagship phone...  None
# 27  The Qi2 standard: https://www.businesswire.com...  None
# 28                     Megapixels? They don't matter.  None
# 29  What exactly is happening with the iPhone's ca...  None
